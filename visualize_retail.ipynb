# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn-darkgrid")

# %%
data = "../datasets/BigBasketProducts.csv"
retail = pd.read_csv(data, index_col="index")
retail.dropna()
# Out:
#                                                  product  \
# index
# 1                 Garlic Oil - Vegetarian Capsule 500 mg
# 2                                  Water Bottle - Orange
# 3                         Brass Angle Deep - Plain, No.2
# 4      Cereal Flip Lid Container/Storage Jar - Assort...
# 5                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27552                                           Rosemary
# 27553                       Peri-Peri Sweet Potato Chips
# 27554                          Green Tea - Pure Original
# 27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# index
# 1            Beauty & Hygiene                 Hair Care
# 2      Kitchen, Garden & Pets     Storage & Accessories
# 3        Cleaning & Household               Pooja Needs
# ...

# %%
# what brand has the higest store goods .
graph = retail["brand"].value_counts().head(2000)
graph.sort_values(na_position="first").plot(kind= "kde", figsize=(16,8)) #Density graph representation.
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
graph.sort_values().plot(kind= "area", figsize=(18,10), xlabel="BRANDS", ylabel="ITEMS")
# Out:
# <AxesSubplot:xlabel='BRANDS', ylabel='ITEMS'>

# %%
retail["average_price"] = (retail.sale_price + retail.market_price)/2
retail["center_price"] = retail.average_price.map(lambda p: p - retail.average_price.mean()) 
retail
# Out:
#                                                  product  \
# index
# 1                 Garlic Oil - Vegetarian Capsule 500 mg
# 2                                  Water Bottle - Orange
# 3                         Brass Angle Deep - Plain, No.2
# 4      Cereal Flip Lid Container/Storage Jar - Assort...
# 5                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27552                                           Rosemary
# 27553                       Peri-Peri Sweet Potato Chips
# 27554                          Green Tea - Pure Original
# 27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# index
# 1            Beauty & Hygiene                 Hair Care
# 2      Kitchen, Garden & Pets     Storage & Accessories
# 3        Cleaning & Household               Pooja Needs
# ...

# %%
retail.brand.describe()
# Out:
# count      27554
# unique      2313
# top       Fresho
# freq         638
# Name: brand, dtype: object

# %%
fruits= retail.loc[(retail.sub_category == "Dry Fruits") & (retail.average_price <= 500)] #checking Dry fruits less than or equals $100 .

# %%
fruits.to_csv("fruit.csv")
fruits.groupby("product")["market_price"].sum().head(500).plot(kind="bar", color="orange", ylabel="Frequency(item-price)", title="Product Market-Price")
# Out:
# <AxesSubplot:title={'center':'Product Market-Price'}, xlabel='product', ylabel='Frequency(item-price)'>

# %%
medical = retail.loc[(retail.sub_category == 'Health & Medicine') & (retail.type == "Supplements & Proteins")]
# df.category.unique()
medical = medical.loc[(medical.brand == "ORGANIC INDIA") & (medical.rating <= 6)]
medical
# Out:
#                          product          category       sub_category  \
# index
# 989    Women Well Being Capsules  Beauty & Hygiene  Health & Medicine
# 4873           Triphala Capsules  Beauty & Hygiene  Health & Medicine
# 6697        Heart Guard Capsules  Beauty & Hygiene  Health & Medicine
# 8146          Osteoseal Capsules  Beauty & Hygiene  Health & Medicine
# 8693            Trikatu Capsules  Beauty & Hygiene  Health & Medicine
# 8761     Beautiful Skin Capsules  Beauty & Hygiene  Health & Medicine
# 10022            Brahmi Capsules  Beauty & Hygiene  Health & Medicine
# 10285       Ashwagandha Capsules  Beauty & Hygiene  Health & Medicine
# 12843     Prostate Care Capsules  Beauty & Hygiene  Health & Medicine
# 13074          Immunity Capsules  Beauty & Hygiene  Health & Medicine
# 13090           Moringa Capsules  Beauty & Hygiene  Health & Medicine
# 15948             Tulsi Capsules  Beauty & Hygiene  Health & Medicine
# ...

# %%
plt.figure(figsize=(16,8))
plt.plot(medical["average_price"],label= "Average Price", color="blue")
plt.plot(medical["sale_price"], label= "Center Price", color="red")


plt.legend(title = "Group")
plt.title("Price By Group", fontsize= 16)
plt.ylabel("Price", fontsize = 14)
plt.xlabel("Index", fontsize = 14)
# Out:
# Text(0.5, 0, 'Index')

# %%
medical.groupby("product")["market_price"].sum().plot(kind="bar", color="orange", ylabel="Frequency(item-price)", title="Product Market-Price")
# Out:
# <AxesSubplot:title={'center':'Product Market-Price'}, xlabel='product', ylabel='Frequency(item-price)'>
